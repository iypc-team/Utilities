# %%
# 1/17/2021-1
from __future__ import absolute_import, division
from IPython.display import clear_output
from BashColors import C

import glob, os, shutil, sys
from time import sleep
from os.path import *
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

import TarfileFunctions
from TarfileFunctions import *
from BashColors import C

contentPath=os.getcwd()
cv2Path = join(contentPath, 'CV2Images')
testPath = join(contentPath, 'images')

if not exists(cv2Path):
    try:
        tff.extractTarfiles('All_CV2_Images.tar.gz')
        sleep(1)
    except FileNotFoundError as err:
        print(err)
        
try: 
    import tensorflow as tf
    print(f'tensorflow: {C.BIBlue}{tf.__version__}{C.ColorOff}')
except ModuleNotFoundError as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install tensorflow
    sleep(1)
    import tensorflow as tf

try: 
    import tensorflow_hub as hub
    print(f'hub: {C.BIBlue}{hub.__version__}{C.ColorOff}')
except Exception as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install --upgrade tensorflow-hub
    sleep(1)
    import tensorflow_hub as hub

try:
    import tflite_model_maker
    print(f'tflite: {C.BIBlue}{tflite_model_maker.__version__}{C.ColorOff}')
except Exception as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install tflite-model-maker
    sleep(1)
    import tflite_model_maker

try: 
    import numpy as np
    print(f'numpy: {C.BIBlue}{np.__version__}{C.ColorOff}')
except ModuleNotFoundError as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install numpy
    sleep(1)
    import numpy as np

try: 
    import cv2
    from cv2 import COLOR_BGR2RGBA, IMREAD_UNCHANGED
    print(f'cv2: {C.BIBlue}{cv2.__version__}{C.ColorOff}')
except ModuleNotFoundError as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install opencv-python-headless # works.
    sleep(1)
    # %pip install opencv-contrib-python-headless
    import cv2
    from cv2 import COLOR_BGR2RGBA, IMREAD_UNCHANGED

try:
    import matplotlib
    from matplotlib import pyplot as plt
    print(f'matplotlib: {C.BIBlue}{matplotlib.__version__}{C.ColorOff}')
except Exception as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install matplotlib
    sleep(1)
    import matplotlib
    from matplotlib import pyplot as plt
    
try:
    import scipy
    print(f'scipy: {C.BIBlue}{scipy.__version__}')
except ModuleNotFoundError as err:
    print(f'\n{C.BIRed}{err}{C.ColorOff}\n')
    # %pip install SciPy
    sleep(1)
    import scipy
    
import CV2_Utils
from CV2_Utils import *

print(C.BIRed)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
sleep(1)

# %%
import logging
logging.getLogger("tensorflow").setLevel(logging.DEBUG)

# %%
# tff.extractTarfiles(fileName='All_CV2_Images.tar.gz')
sleep(1)
tff.extractTarfiles(fileName='CV2Images.tar.gz')
sleep(1)
tff.extractTarfiles(fileName='DataGenerator.tar.gz')
sleep(1)
tff.extractTarfiles(fileName='Validation.tar.gz')
sleep(1)
tff.extractTarfiles(fileName='data.tar.gz')
sleep(1)
tff.extractTarfiles(fileName='images.tar.gz')
sleep(1)

# %%
alreadyInstalledList=set([each.split('.')[0] for each in sys.modules.keys()])
modul = sys.modules.keys()

for idx, item in enumerate(alreadyInstalledList):
    if item in sorted(alreadyInstalledList):
        print(f'{idx} {C.BIBlue}{item}{C.ColorOff}')
